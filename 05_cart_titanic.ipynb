# %% [markdown]
# # Exercise: Titanic
#
# BUSMGT 7247

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_validate, train_test_split
from matplotlib import pyplot as plt

# Seed the random number generator for reproducible results
np.random.seed(10)

# %%
df = pd.read_csv('data/titanic.csv')
df.head()
# Out:
#    Passenger ID  Passenger Class  Survived  \
# 0             1                1         1
# 1             2                1         1
# 2             3                1         0
# 3             4                1         0
# 4             5                1         0
#
#                                               Name     Sex      Age  \
# 0                    Allen, Miss. Elisabeth Walton  Female  29.0000
# 1                   Allison, Master. Hudson Trevor    Male   0.9167
# 2                     Allison, Miss. Helen Loraine  Female   2.0000
# 3             Allison, Mr. Hudson Joshua Creighton    Male  30.0000
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.0000
#
#    On-Board Siblings or Spouses  On-Board Parents or Children Ticket Number  \
# 0                             0                             0         24160
# 1                             1                             2        113781
# 2                             1                             2        113781
# 3                             1                             2        113781
# 4                             1                             2        113781
#
#        Fare    Cabin Port of Embarkation                      Destination
# 0  211.3375       B5         Southampton                     St Louis, MO
# 1  151.5500  C22 C26         Southampton  Montreal, PQ / Chesterville, ON
# 2  151.5500  C22 C26         Southampton  Montreal, PQ / Chesterville, ON
# 3  151.5500  C22 C26         Southampton  Montreal, PQ / Chesterville, ON
# 4  151.5500  C22 C26         Southampton  Montreal, PQ / Chesterville, ON
